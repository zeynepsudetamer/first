# %%
import pandas as pd
df=pd.read_csv("Salary_Data.csv")
df
# Out:
#     YearsExperience   Age  Salary
# 0               1.1  21.0   39343
# 1               1.3  21.5   46205
# 2               1.5  21.7   37731
# 3               2.0  22.0   43525
# 4               2.2  22.2   39891
# 5               2.9  23.0   56642
# 6               3.0  23.0   60150
# 7               3.2  23.3   54445
# 8               3.2  23.3   64445
# 9               3.7  23.6   57189
# 10              3.9  23.9   63218
# 11              4.0  24.0   55794
# 12              4.0  24.0   56957
# 13              4.1  24.0   57081
# 14              4.5  25.0   61111
# 15              4.9  25.0   67938
# 16              5.1  26.0   66029
# 17              5.3  27.0   83088
# 18              5.9  28.0   81363
# 19              6.0  29.0   93940
# 20              6.8  30.0   91738
# 21              7.1  30.0   98273
# 22              7.9  31.0  101302
# 23              8.2  32.0  113812
# 24              8.7  33.0  109431
# 25              9.0  34.0  105582
# ...

# %%
age_filter=df['Age']==25.0
df[age_filter]
# Out:
#     YearsExperience   Age  Salary
# 14              4.5  25.0   61111
# 15              4.9  25.0   67938

# %%
df.sort_values('Age',ascending=False,inplace=True)

# %%
df.sort_index(ascending=False)
# Out:
#     YearsExperience   Age  Salary
# 29             10.5  38.0  121872
# 28             10.3  37.0  122391
# 27              9.6  36.0  112635
# 26              9.5  35.0  116969
# 25              9.0  34.0  105582
# 24              8.7  33.0  109431
# 23              8.2  32.0  113812
# 22              7.9  31.0  101302
# 21              7.1  30.0   98273
# 20              6.8  30.0   91738
# 19              6.0  29.0   93940
# 18              5.9  28.0   81363
# 17              5.3  27.0   83088
# 16              5.1  26.0   66029
# 15              4.9  25.0   67938
# 14              4.5  25.0   61111
# 13              4.1  24.0   57081
# 12              4.0  24.0   56957
# 11              4.0  24.0   55794
# 10              3.9  23.9   63218
# 9               3.7  23.6   57189
# 8               3.2  23.3   64445
# 7               3.2  23.3   54445
# 6               3.0  23.0   60150
# 5               2.9  23.0   56642
# 4               2.2  22.2   39891
# ...

# %%
df.nlargest(10,'Age')
# Out:
#     YearsExperience   Age  Salary
# 29             10.5  38.0  121872
# 28             10.3  37.0  122391
# 27              9.6  36.0  112635
# 26              9.5  35.0  116969
# 25              9.0  34.0  105582
# 24              8.7  33.0  109431
# 23              8.2  32.0  113812
# 22              7.9  31.0  101302
# 21              7.1  30.0   98273
# 20              6.8  30.0   91738

# %%
df.describe()
# Out:
#        YearsExperience        Age         Salary
# count        30.000000  30.000000      30.000000
# mean          5.313333  27.216667   76003.000000
# std           2.837888   5.161267   27414.429785
# min           1.100000  21.000000   37731.000000
# 25%           3.200000  23.300000   56720.750000
# 50%           4.700000  25.000000   65237.000000
# 75%           7.700000  30.750000  100544.750000
# max          10.500000  38.000000  122391.000000

# %%
df['Age'].mean()
# Out:
# 27.216666666666665

# %%
df['Salary'].value_counts()
# Out:
# Salary
# 121872    1
# 122391    1
# 46205     1
# 37731     1
# 43525     1
# 39891     1
# 56642     1
# 60150     1
# 54445     1
# 64445     1
# 57189     1
# 63218     1
# 55794     1
# 56957     1
# 57081     1
# 61111     1
# 67938     1
# 66029     1
# 83088     1
# 81363     1
# 93940     1
# 91738     1
# 98273     1
# 101302    1
# 113812    1
# 109431    1
# 105582    1
# 116969    1
# 112635    1
# 39343     1
# Name: count, dtype: int64

# %%
df['YearsExperience'].plot(kind='line', title='Saatlik Trafik Değişimi')
# Out:
# <Axes: title={'center': 'Saatlik Trafik Değişimi'}>

# %%
df["Salary"].plot(kind='line',title="yaş degişimi")
# Out:
# <Axes: title={'center': 'yaş degişimi'}>

# %%
df["YearsExperience"].plot(kind="bar",title="yıllık değişim")
# Out:
# <Axes: title={'center': 'yıllık değişim'}>

# %%
df["Salary"].plot(kind="hist",title="salary")
# Out:
# <Axes: title={'center': 'salary'}, ylabel='Frequency'>
